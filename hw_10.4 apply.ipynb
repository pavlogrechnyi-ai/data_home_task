# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
data_path = r"C:\Users\limon.DESKTOP-D4OD6GD\OneDrive\Desktop\Навчання\python\supermarket_sales.csv"
df = pd.read_csv(data_path)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum().sort_values(ascending=False)
# Out:
# Branch
# C    5265.1765
# A    5057.1605
# B    5057.0320
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.groupby('City')['gross income'].sum().sort_values(ascending=False)
# Out:
# City
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Mandalay     5057.0320
# Name: gross income, dtype: float64

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(
    index='Branch',
    columns='Product line',
    values='Invoice ID',
    aggfunc='count'
)

invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].sort_values(ascending=False)
# Out:
# Branch
# A    60
# B    55
# C    55
# Name: Electronic accessories, dtype: int64

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %%
df.groupby('Customer type')['Total'].mean().round(2)
# Out:
# Customer type
# Member    327.79
# Normal    318.12
# Name: Total, dtype: float64

# %% [markdown]
# Якщо Member витрачають більше:
# - варто активніше залучати клієнтів у програму лояльності;
# - бонуси реально збільшують прибуток;

# %%
df.groupby(['City','Product line'])['gross income'].sum().sort_values(ascending=False)
# Out:
# City       Product line
# Naypyitaw  Food and beverages        1131.7550
# Yangon     Home and lifestyle        1067.4855
# Naypyitaw  Fashion accessories       1026.6700
# Mandalay   Sports and travel          951.8190
#            Health and beauty          951.4600
# Yangon     Sports and travel          922.5095
# Naypyitaw  Electronic accessories     903.2845
# Yangon     Electronic accessories     872.2435
# Mandalay   Home and lifestyle         835.6745
# Yangon     Food and beverages         817.2905
# Mandalay   Electronic accessories     811.9735
# Naypyitaw  Health and beauty          791.2060
# Mandalay   Fashion accessories        781.5865
# Yangon     Fashion accessories        777.7385
# Naypyitaw  Sports and travel          750.5680
# Mandalay   Food and beverages         724.5185
# Naypyitaw  Home and lifestyle         661.6930
# Yangon     Health and beauty          599.8930
# Name: gross income, dtype: float64

# %% [markdown]
# Бізнес-висновок:
# - можна адаптувати асортимент під кожне місто;
# - інвестувати більше в найприбутковіші категорії;
# - прибрати слабкі позиції.

# %%
df['Hour'] = df['Time'].apply(lambda x: int(x.split(':')[0]))
df.groupby('Hour')['Total'].mean().round(2)
# Out:
# Hour
# 10    311.10
# 11    337.53
# 12    292.88
# 13    337.12
# 14    371.43
# 15    305.68
# 16    327.61
# 17    330.34
# 18    279.90
# 19    351.32
# 20    306.26
# Name: Total, dtype: float64

# %% [markdown]
# Найвищий середній чек спостерігається о 14:00 та 19:00. Це може свідчити про те, що в ці години клієнти здійснюють більш заплановані або великі покупки (обідні закупівлі та покупки після роботи). У вечірній час клієнти мають більшу готовність витрачати кошти, що робить ці години ключовими для промоакцій та продажу товарів з вищою маржинальністю.

# %% [markdown]
# Бізнес-рекомендації:
#
# - запускати преміум-пропозиції в ці години;
# - підсилювати персонал;
# - робити апселл дорогих товарів;
# - рекламувати акції перед 14:00 і 19:00.
